# %%
import numpy as np
import pandas as pd


#models = ['gem1', 'gem1-gamma11', 'gem1-gamma12', 'gem1-gamma11-gc2']
models = ['gem1']
seeds = [0, 1, 2, 3]


def get_ensemble_dataset(models, seeds, phase='val'):
    X, y = [], []
    for model in models:
        for seed in seeds:
            dfs = []
            for fold in range(10):
                df = pd.read_csv(f'outputs/{model}/fold{fold}/seed{seed}/{phase}_preds.csv')
                dfs.append(df)
            
            if phase == 'val':
                stacked_df = pd.concat(dfs, axis=0)
                X.append(stacked_df[stacked_df.columns[-2:]].values)
                y.append(stacked_df[['Reorg_g', 'Reorg_ex']].values)
            else:
                mean_X = np.mean([df[df.columns[-2:]].values for df in dfs], axis=0)
                X.append(mean_X)
    X = np.concatenate(X, axis=1)
    y = np.concatenate(y, axis=0) if phase == 'val' else None

    return X, y


train_X, train_y = get_ensemble_dataset(models, seeds, phase='val')
test_X, _ = get_ensemble_dataset(models, seeds, phase='test')

print(train_X.shape, train_y.shape)
print(test_X.shape)
# Out:
# (18157, 8) (72628, 2)
# (457, 8)

# %%
import xgboost as xgb
from sklearn.model_selection import KFold


preds = []

kfold = KFold(n_splits=7, shuffle=True, random_state=0)

for train_idx, val_idx in kfold.split(train_X):
    X_train, y_train = train_X[train_idx], train_y[train_idx]
    X_val, y_val = train_X[val_idx], train_y[val_idx]
    model = xgb.XGBRegressor(gpu_id=1)
    model.fit(X_train, y_train, eval_set=[(X_val, y_val)], early_stopping_rounds=20)
    preds.append(model.predict(test_X))

preds = np.mean(preds, axis=0)
sub = pd.read_csv('data/sample_submission.csv')
sub['Reorg_g'] = preds[:, 0]
sub['Reorg_ex'] = preds[:, 1]
sub.to_csv('outputs/ensembled_submission.csv', index=False)
# Out:
# [0]	validation_0-rmse:0.26961
# [1]	validation_0-rmse:0.20640
# [2]	validation_0-rmse:0.16669
# [3]	validation_0-rmse:0.14314
# [4]	validation_0-rmse:0.13015
# [5]	validation_0-rmse:0.12357
# [6]	validation_0-rmse:0.12029
# [7]	validation_0-rmse:0.11862
# [8]	validation_0-rmse:0.11795
# [9]	validation_0-rmse:0.11758
# [10]	validation_0-rmse:0.11736
# [11]	validation_0-rmse:0.11730
# [12]	validation_0-rmse:0.11740
# [13]	validation_0-rmse:0.11747
# [14]	validation_0-rmse:0.11734
# [15]	validation_0-rmse:0.11729
# [16]	validation_0-rmse:0.11726
# [17]	validation_0-rmse:0.11751
# [18]	validation_0-rmse:0.11766
# [19]	validation_0-rmse:0.11779
# [20]	validation_0-rmse:0.11797
# [21]	validation_0-rmse:0.11803
# [22]	validation_0-rmse:0.11806
# [23]	validation_0-rmse:0.11810
# [24]	validation_0-rmse:0.11812
# [25]	validation_0-rmse:0.11815
# [26]	validation_0-rmse:0.11812
# [27]	validation_0-rmse:0.11830
# [28]	validation_0-rmse:0.11830
# [29]	validation_0-rmse:0.11838
# [30]	validation_0-rmse:0.11826
# [31]	validation_0-rmse:0.11850
# [32]	validation_0-rmse:0.11854
# [33]	validation_0-rmse:0.11848
# [34]	validation_0-rmse:0.11851
# [35]	validation_0-rmse:0.11860
# [0]	validation_0-rmse:0.27107
# [1]	validation_0-rmse:0.20628
# [2]	validation_0-rmse:0.16526
# [3]	validation_0-rmse:0.14082
# [4]	validation_0-rmse:0.12710
# [5]	validation_0-rmse:0.11977
# [6]	validation_0-rmse:0.11592
# [7]	validation_0-rmse:0.11398
# [8]	validation_0-rmse:0.11295
# [9]	validation_0-rmse:0.11244
# [10]	validation_0-rmse:0.11210
# [11]	validation_0-rmse:0.11205
# [12]	validation_0-rmse:0.11207
# [13]	validation_0-rmse:0.11224
# [14]	validation_0-rmse:0.11222
# [15]	validation_0-rmse:0.11228
# [16]	validation_0-rmse:0.11238
# [17]	validation_0-rmse:0.11248
# [18]	validation_0-rmse:0.11254
# [19]	validation_0-rmse:0.11272
# [20]	validation_0-rmse:0.11277
# [21]	validation_0-rmse:0.11274
# [22]	validation_0-rmse:0.11282
# [23]	validation_0-rmse:0.11288
# [24]	validation_0-rmse:0.11295
# [25]	validation_0-rmse:0.11297
# [26]	validation_0-rmse:0.11287
# [27]	validation_0-rmse:0.11288
# [28]	validation_0-rmse:0.11301
# [29]	validation_0-rmse:0.11313
# [30]	validation_0-rmse:0.11321
# [31]	validation_0-rmse:0.11327
# [0]	validation_0-rmse:0.27120
# [1]	validation_0-rmse:0.20754
# [2]	validation_0-rmse:0.16782
# [3]	validation_0-rmse:0.14415
# [4]	validation_0-rmse:0.13139
# [5]	validation_0-rmse:0.12463
# [6]	validation_0-rmse:0.12120
# [7]	validation_0-rmse:0.11967
# [8]	validation_0-rmse:0.11879
# [9]	validation_0-rmse:0.11861
# [10]	validation_0-rmse:0.11876
# [11]	validation_0-rmse:0.11872
# [12]	validation_0-rmse:0.11874
# [13]	validation_0-rmse:0.11885
# [14]	validation_0-rmse:0.11895
# [15]	validation_0-rmse:0.11882
# [16]	validation_0-rmse:0.11889
# [17]	validation_0-rmse:0.11887
# [18]	validation_0-rmse:0.11905
# [19]	validation_0-rmse:0.11917
# [20]	validation_0-rmse:0.11924
# [21]	validation_0-rmse:0.11930
# [22]	validation_0-rmse:0.11927
# [23]	validation_0-rmse:0.11931
# [24]	validation_0-rmse:0.11928
# [25]	validation_0-rmse:0.11927
# [26]	validation_0-rmse:0.11945
# [27]	validation_0-rmse:0.11947
# [28]	validation_0-rmse:0.11949
# [0]	validation_0-rmse:0.27217
# [1]	validation_0-rmse:0.20843
# [2]	validation_0-rmse:0.16834
# [3]	validation_0-rmse:0.14477
# [4]	validation_0-rmse:0.13160
# [5]	validation_0-rmse:0.12458
# [6]	validation_0-rmse:0.12100
# [7]	validation_0-rmse:0.11915
# [8]	validation_0-rmse:0.11816
# [9]	validation_0-rmse:0.11777
# [10]	validation_0-rmse:0.11754
# [11]	validation_0-rmse:0.11739
# [12]	validation_0-rmse:0.11722
# [13]	validation_0-rmse:0.11734
# [14]	validation_0-rmse:0.11729
# [15]	validation_0-rmse:0.11730
# [16]	validation_0-rmse:0.11724
# [17]	validation_0-rmse:0.11731
# [18]	validation_0-rmse:0.11724
# [19]	validation_0-rmse:0.11728
# [20]	validation_0-rmse:0.11722
# [21]	validation_0-rmse:0.11741
# [22]	validation_0-rmse:0.11743
# [23]	validation_0-rmse:0.11746
# [24]	validation_0-rmse:0.11740
# [25]	validation_0-rmse:0.11754
# [26]	validation_0-rmse:0.11751
# [27]	validation_0-rmse:0.11763
# [28]	validation_0-rmse:0.11784
# [29]	validation_0-rmse:0.11793
# [30]	validation_0-rmse:0.11816
# [31]	validation_0-rmse:0.11820
# [0]	validation_0-rmse:0.27676
# [1]	validation_0-rmse:0.21156
# [2]	validation_0-rmse:0.17077
# [3]	validation_0-rmse:0.14646
# [4]	validation_0-rmse:0.13278
# [5]	validation_0-rmse:0.12534
# [6]	validation_0-rmse:0.12146
# [7]	validation_0-rmse:0.11974
# [8]	validation_0-rmse:0.11894
# [9]	validation_0-rmse:0.11858
# [10]	validation_0-rmse:0.11828
# [11]	validation_0-rmse:0.11830
# [12]	validation_0-rmse:0.11832
# [13]	validation_0-rmse:0.11837
# [14]	validation_0-rmse:0.11843
# [15]	validation_0-rmse:0.11852
# [16]	validation_0-rmse:0.11882
# [17]	validation_0-rmse:0.11887
# [18]	validation_0-rmse:0.11886
# [19]	validation_0-rmse:0.11888
# [20]	validation_0-rmse:0.11888
# [21]	validation_0-rmse:0.11886
# [22]	validation_0-rmse:0.11883
# [23]	validation_0-rmse:0.11900
# [24]	validation_0-rmse:0.11911
# [25]	validation_0-rmse:0.11916
# [26]	validation_0-rmse:0.11928
# [27]	validation_0-rmse:0.11925
# [28]	validation_0-rmse:0.11932
# [29]	validation_0-rmse:0.11943
# [0]	validation_0-rmse:0.27435
# [1]	validation_0-rmse:0.21043
# [2]	validation_0-rmse:0.16987
# [3]	validation_0-rmse:0.14556
# [4]	validation_0-rmse:0.13194
# [5]	validation_0-rmse:0.12466
# [6]	validation_0-rmse:0.12078
# [7]	validation_0-rmse:0.11903
# [8]	validation_0-rmse:0.11816
# [9]	validation_0-rmse:0.11789
# [10]	validation_0-rmse:0.11794
# [11]	validation_0-rmse:0.11801
# [12]	validation_0-rmse:0.11791
# [13]	validation_0-rmse:0.11802
# [14]	validation_0-rmse:0.11787
# [15]	validation_0-rmse:0.11797
# [16]	validation_0-rmse:0.11808
# [17]	validation_0-rmse:0.11811
# [18]	validation_0-rmse:0.11808
# [19]	validation_0-rmse:0.11817
# [20]	validation_0-rmse:0.11822
# [21]	validation_0-rmse:0.11824
# [22]	validation_0-rmse:0.11826
# [23]	validation_0-rmse:0.11824
# [24]	validation_0-rmse:0.11829
# [25]	validation_0-rmse:0.11842
# [26]	validation_0-rmse:0.11854
# [27]	validation_0-rmse:0.11849
# [28]	validation_0-rmse:0.11856
# [29]	validation_0-rmse:0.11857
# [30]	validation_0-rmse:0.11870
# [31]	validation_0-rmse:0.11861
# [32]	validation_0-rmse:0.11860
# [33]	validation_0-rmse:0.11866
# [0]	validation_0-rmse:0.27598
# [1]	validation_0-rmse:0.21105
# [2]	validation_0-rmse:0.17056
# [3]	validation_0-rmse:0.14658
# [4]	validation_0-rmse:0.13337
# [5]	validation_0-rmse:0.12649
# [6]	validation_0-rmse:0.12304
# [7]	validation_0-rmse:0.12149
# [8]	validation_0-rmse:0.12096
# [9]	validation_0-rmse:0.12035
# [10]	validation_0-rmse:0.12043
# [11]	validation_0-rmse:0.12041
# [12]	validation_0-rmse:0.12043
# [13]	validation_0-rmse:0.12041
# [14]	validation_0-rmse:0.12080
# [15]	validation_0-rmse:0.12094
# [16]	validation_0-rmse:0.12096
# [17]	validation_0-rmse:0.12091
# [18]	validation_0-rmse:0.12107
# [19]	validation_0-rmse:0.12117
# [20]	validation_0-rmse:0.12128
# [21]	validation_0-rmse:0.12122
# [22]	validation_0-rmse:0.12127
# [23]	validation_0-rmse:0.12144
# [24]	validation_0-rmse:0.12136
# [25]	validation_0-rmse:0.12146
# [26]	validation_0-rmse:0.12153
# [27]	validation_0-rmse:0.12160
# [28]	validation_0-rmse:0.12176
# [29]	validation_0-rmse:0.12179
